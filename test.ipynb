# %%
from collections import Counter

num=[1,2,2,2]
num_counter= Counter(num)
print(num_counter)
# Out:
# Counter({2: 3, 1: 1})

# %%
import pandas as pd

df = pd.DataFrame({'Name': ['Alice', 'Bob','Dan'], 'Score': [85, 90,0]})
df=df['Score'].apply(lambda x:x if x!=0 else df[df['Score']!=0]['Score'].mean())
#df=df['Score'].replace(0,df['Score'][df['Score']!=0].mean())
print(df)
# Out:
# 0    85.0
# 1    90.0
# 2    87.5
# Name: Score, dtype: float64

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}

df = pd.DataFrame(data)

df.apply(lambda x: x**2)
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(6, 4), columns=list('ABCD'))
print(df.drop()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 import numpy as np
#       2 df = pd.DataFrame(np.random.randn(6, 4), columns=list('ABCD'))
# ----> 3 print(df.drop())
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:4636, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4632             axes = {"index": index}
#    4633             if self.ndim == 2:
#    4634                 axes["columns"] = columns
#    4635         else:
# -> 4636             raise ValueError(
#    4637                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4638             )
#    4639
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'
